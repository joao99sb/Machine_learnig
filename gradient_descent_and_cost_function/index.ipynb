# %% [markdown]
# # The Mean squered error (or in this case the cost function) is defined by
#
# ![image.png](attachment:e9f981e4-b1c4-4889-b2ca-84ea57f6129a.png)

# %% [markdown]
# ## In linear regression we can replace to
#
# CF = (1/n) * sum((yi - (m * xi + b))²)
#
# when de d(CF)/dm = d(CF)/db = 0
# this means that the error of this functions is minimum
#
# d(CF)/dm = -(2/n) * sum (xi * (yi - (m * xi + b )))
#
# d(CF)/db = -(2/n) * sum (yi - (m * xi + b ))

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn import linear_model

# %%
 def gradient_descent(x,y):
    m_curr = b_curr = 0
    n = len(x)
    learning_rate = 0.009
    iterations = 10000
     
    for i in range(iterations):
        y_predicted = m_curr *x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md =  -(2/n) * sum(x*(y-y_predicted))
        bd = -(2/n) * sum(y-y_predicted)
        m_curr = m_curr - learning_rate *md
        b_curr = b_curr - learning_rate *bd
        
    print(f"m: {m_curr}, b: {b_curr}, cost {cost}")
    return (m_curr,b_curr)

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

(m,b) = gradient_descent(x,y)
# Out:
# m: 2.0000000000000404, b: 2.9999999999998557

# %%
def y_predict(x,m,b):
    return x*m + b

# %%
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x,y,color='red',marker="+")

plt.show()

plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x,y,color='red',marker="+")

y_predict = y_predict(x,m,b)
print(y_predict)

plt.plot(x,y_predict,color='blue')
plt.show()
# Out:
# [ 5.  7.  9. 11. 13.]
